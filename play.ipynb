# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import matplotlib


# %matplotlib tkagg

# %%
fig1 = plt.figure()
manager1 = plt._pylab_helpers.Gcf.get_fig_manager(fig1.number)
window1 = manager1.window

# %%
print(window1.geometry())
print(window1.attributes())
# Out:
# 640x514+56+43
# ('-alpha', 1.0, '-fullscreen', 0, '-modified', 0, '-notify', 0, '-titlepath', '', '-topmost', 0, '-transparent', 0, '-type', 'unsupported')

# %%
'1920x1080+1512+0'
'1920x1080+1512+0'
'1505x1200+-466+-1340'

# Set window geometry to: 300x300+1512+0, fullscreen: True
# Set window geometry to: 1505x1200+-466+-1340, fullscreen: False

# %%
window1.geometry('300x300+1512+0')
# window.attributes('-fullscreen', True)
# Out:
# ''

# %%
window1.attributes('-fullscreen', True)
# Out:
# 'None'

# %%
fig2 = plt.figure()
manager2 = plt._pylab_helpers.Gcf.get_fig_manager(fig2.number)
window2 = manager2.window

# %%
window2.geometry('1505x1200+-466+-1340')
# Out:
# ''
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
